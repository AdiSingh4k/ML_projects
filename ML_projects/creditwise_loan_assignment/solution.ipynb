# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv("loan_approval_data.csv")
print(df.shape)
df=df.dropna()
x=df.drop(columns=["Applicant_ID", "Gender", "Loan_Approved", "Education_Level"])
df.shape
y=df["Loan_Approved"]
#x = pd.get_dummies(x, columns=["Employment_Status", "Marital_Status", "Loan_Purpose", "Property_Area", "Employer_Category"], drop_first=True)
x = pd.get_dummies(x, columns=["Employment_Status", "Marital_Status", "Loan_Purpose", "Property_Area", "Employer_Category"], drop_first=True)
# Out:
# (1000, 20)

# %%
x
# Out:
#      Applicant_Income  Coapplicant_Income   Age  Dependents  Credit_Score  \
# 0             17795.0              1387.0  51.0         0.0         637.0
# 3             13964.0              8173.0  40.0         2.0         579.0
# 5              8265.0              4831.0  53.0         1.0         602.0
# 6             18850.0              2768.0  58.0         0.0         687.0
# 10            18023.0              4033.0  52.0         2.0         688.0
# ..                ...                 ...   ...         ...           ...
# 985           10705.0              7898.0  33.0         1.0         704.0
# 987            6841.0              2293.0  34.0         2.0         639.0
# 993           16596.0              6007.0  33.0         2.0         688.0
# 997           15192.0              8433.0  48.0         1.0         666.0
# 998            9083.0              7380.0  50.0         1.0         748.0
#
#      Existing_Loans  DTI_Ratio  Savings  Collateral_Value  Loan_Amount  ...  \
# ...

# %%
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2, random_state=42)

# %%
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)
x_train_scaled
# Out:
# array([[-0.56731363,  1.10067593, -0.69967985, ...,  2.25542823,
#         -0.7628374 , -0.35284273],
#        [-0.07002663,  0.76262948,  1.77787503, ...,  2.25542823,
#         -0.7628374 , -0.35284273],
#        [ 0.53143512, -0.80741618,  0.49321694, ..., -0.44337478,
#          1.31089534, -0.35284273],
#        ...,
#        [-1.82153828, -0.60237161,  1.04378469, ..., -0.44337478,
#         -0.7628374 , -0.35284273],
#        [ 1.00120426,  0.34457408, -0.60791856, ..., -0.44337478,
#         -0.7628374 , -0.35284273],
#        [-1.65937948,  1.44183961, -0.51615727, ...,  2.25542823,
#         -0.7628374 , -0.35284273]], shape=(280, 25))

# %%
model=LogisticRegression()
model.fit(x_train_scaled, y_train)
y_pred=model.predict(x_test_scaled)
y_pred
# Out:
# array(['Yes', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'Yes', 'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No',
#        'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No', 'No', 'Yes',
#        'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No',
#        'No', 'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'Yes',
#        'No', 'Yes', 'No', 'No', 'No', 'No', 'No', 'Yes', 'No'],
#       dtype=object)

# %%
y_test
# Out:
# 433     No
# 980     No
# 909    Yes
# 664    Yes
# 427     No
#       ...
# 505     No
# 500     No
# 545     No
# 941    Yes
# 653     No
# Name: Loan_Approved, Length: 71, dtype: object

# %%
print("accuracy: ", accuracy_score(y_test, y_pred))
print("f1 score: ", f1_score(y_test, y_pred, average="macro"))
print("precision: ", precision_score(y_test, y_pred,  average="macro"))
print("recall: ", recall_score(y_test, y_pred,  average="macro"))
# Out:
# accuracy:  0.8028169014084507
# f1 score:  0.7694805194805194
# precision:  0.7771428571428571
# recall:  0.7635869565217391

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
model.fit(x_train_scaled, y_train)
y_pred=model.predict(x_test_scaled)
print("accuracy: ", accuracy_score(y_test, y_pred))
print("f1 score: ", f1_score(y_test, y_pred, average="macro"))
print("precision: ", precision_score(y_test, y_pred,  average="macro"))
print("recall: ", recall_score(y_test, y_pred,  average="macro"))
# Out:
# accuracy:  0.8028169014084507
# f1 score:  0.7484817813765182
# precision:  0.8017857142857143
# recall:  0.7296195652173914

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.80      0.94      0.87        48
#          Yes       0.80      0.52      0.63        23
#
#     accuracy                           0.80        71
#    macro avg       0.80      0.73      0.75        71
# weighted avg       0.80      0.80      0.79        71
